# %%
# %matplotlib inline
from pylab import *
import scipy as sp
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pylab as ply
import matplotlib.patches as mpatches
from matplotlib.gridspec import GridSpec
import random
from matplotlib.gridspec import GridSpec
from operator import itemgetter
from mpl_toolkits.axes_grid1 import make_axes_locatable

#!/usr/bin/env python
# -*- coding: utf-8 -*-
from __future__ import unicode_literals

# %%
imp_aug_2974 = np.load('imp_aug_mapa162.npy')
imp_obs_2974 = np.load('imp_obs_mapa162.npy')
imp_km_2974  = np.load('imp_km_mapa162.npy')




NA02 = [round((35296-35100)),round((751900 - 751732))]
NA04 = [round((35542-35100)),round((751900 - 751551))]
NA07 = np.array([round((353272-351000)/10),round((7519000 - 7518072)/10)])
NA12 = np.array([round((354587-351000)/10),round((7519000 - 7516745)/10)])
NA37 = np.array([round((355387-351000)/10),round((7519000 - 7516362)/10)])
RJS19= np.array([round((353886-351000)/10),round((7519000 - 7516462)/10)])
RJS42= np.array([round((352040-351000)/10),round((7519000 - 7518180)/10)])

print (NA02,NA04,NA07,NA12,NA37,RJS19)
'''

imp_obs_2974[NA02[1] ,NA02[0]]  = -290000
imp_obs_2974[NA04[1] ,NA04[0]]  = -290000
imp_obs_2974[NA07[1] ,NA07[0]]  = -290000
imp_obs_2974[RJS19[1],RJS19[0]] = -290000'''

plt.matshow(imp_obs_2974,vmin=20000,vmax=29000)
plt.text(NA02[0],NA02[1], 'NA02');plt.plot(NA02[0],NA02[1],'.k')
plt.text(NA04[0],NA04[1], 'NA04');plt.plot(NA04[0],NA04[1],'.k')
plt.text(NA07[0],NA07[1], 'NA07');plt.plot(NA07[0],NA07[1],'.k')
plt.text(NA12[0],NA12[1], 'NA12');plt.plot(NA12[0],NA12[1],'.k')
plt.text(NA37[0],NA37[1], 'NA37');plt.plot(NA37[0],NA37[1],'.k')
plt.text(RJS19[0],RJS19[1], 'RJS19');plt.plot(RJS19[0],RJS19[1],'.k')
plt.text(RJS42[0],RJS42[1], 'RJS42');plt.plot(RJS42[0],RJS42[1],'.k')
plt.colorbar()
plt.show()
# Out:
# [196, 168] [442, 349] [227  93] [359 226] [439 264] [289 254]

# %%
fig, axes = plt.subplots(nrows=1, ncols=3)
fig.set_size_inches(15, 10)

#tick = np.linspace(np.min(imp_obs_2974),np.max(imp_obs_2974),10)

plt.tight_layout(pad=0.5, w_pad=2.5, h_pad=2.0)
ax1 = plt.subplot(131) # creates first axis
i1 = ax1.imshow(imp_obs_2974,cmap='jet',vmin=20000,vmax=35000)
cb1 = plt.colorbar(i1, shrink=0.30)
plt.contourf(imp_obs_2974, 15, alpha=.75, cmap='jet',vmin=20000,vmax=35000)
plt.title('$Z_{obs}$')
plt.text(NA02[0],NA02[1], 'NA02');plt.plot(NA02[0],NA02[1],'.k')
plt.text(NA04[0],NA04[1], 'NA04');plt.plot(NA04[0],NA04[1],'.k')
plt.text(NA07[0],NA07[1], 'NA07');plt.plot(NA07[0],NA07[1],'.k')
plt.text(NA12[0],NA12[1], 'NA12');plt.plot(NA12[0],NA12[1],'.k')
plt.text(NA37[0],NA37[1], 'NA37');plt.plot(NA37[0],NA37[1],'.k')
plt.text(RJS19[0],RJS19[1], 'RJS19');plt.plot(RJS19[0],RJS19[1],'.k')
plt.text(RJS42[0],RJS42[1], 'RJS42');plt.plot(RJS42[0],RJS42[1],'.k')
#-------------------------#
ax1.set_xticklabels([351,351,352,353,354,355,356])
ax1.set_yticklabels([7519,7519," ",7518," ",7517," ",7516," ",7515])
ax1.set_ylabel('UTM coordinates (km)')
ax1.set_xlabel('UTM coordinates (km)')
ax1.grid()
#------------------------------------------------------------------------------------------------------#
ax2 = plt.subplot(132) # creates second axis
i2=ax2.imshow(imp_km_2974,cmap='jet',vmin=20000,vmax=29000)
cb2 = plt.colorbar(i2, shrink=0.30)
plt.contourf(imp_km_2974, 15, alpha=.75, cmap='jet',vmin=20000,vmax=29000)
plt.title('$Z_{KM}$')

plt.text(NA02[0],NA02[1], 'NA02');plt.plot(NA02[0],NA02[1],'.k')
plt.text(NA04[0],NA04[1], 'NA04');plt.plot(NA04[0],NA04[1],'.k')
plt.text(NA07[0],NA07[1], 'NA07', color='white');plt.plot(NA07[0],NA07[1],'.w')
plt.text(NA12[0],NA12[1], 'NA12');plt.plot(NA12[0],NA12[1],'.k')
plt.text(NA37[0],NA37[1], 'NA37');plt.plot(NA37[0],NA37[1],'.k')
plt.text(RJS19[0],RJS19[1], 'RJS19');plt.plot(RJS19[0],RJS19[1],'.k')
plt.text(RJS42[0],RJS42[1], 'RJS42');plt.plot(RJS42[0],RJS42[1],'.k')
#-------------------------#
ax2.set_xticklabels([351,351,352,353,354,355,356])
ax2.set_yticklabels([7519,7519," ",7518," ",7517," ",7516," ",7515])
ax2.set_xlabel('UTM coordinates (km)')
ax2.grid()
#------------------------------------------------------------------------------------------------------#
#plt.tight_layout(pad=0.5, w_pad=2.5, h_pad=2.0)
ax3 = plt.subplot(133) # creates first axis
i3 = ax3.imshow(imp_aug_2974,cmap='jet',vmin=20000,vmax=29000)
cb3 = plt.colorbar(i3, shrink=0.30)
plt.contourf(imp_aug_2974, 15, alpha=.75, cmap='jet',vmin=20000,vmax=29000)
plt.title('$Z_e$')

plt.text(NA02[0],NA02[1], 'NA02');plt.plot(NA02[0],NA02[1],'.k')
plt.text(NA04[0],NA04[1], 'NA04');plt.plot(NA04[0],NA04[1],'.k')
plt.text(NA07[0],NA07[1], 'NA07');plt.plot(NA07[0],NA07[1],'.k')
plt.text(NA12[0],NA12[1], 'NA12');plt.plot(NA12[0],NA12[1],'.k')
plt.text(NA37[0],NA37[1], 'NA37', color='white');plt.plot(NA37[0],NA37[1],'.w')
plt.text(RJS19[0],RJS19[1], 'RJS19');plt.plot(RJS19[0],RJS19[1],'.k')
plt.text(RJS42[0],RJS42[1], 'RJS42');plt.plot(RJS42[0],RJS42[1],'.k')
#-------------------------#
ax3.set_xticklabels([351,351,352,353,354,355,356])
ax3.set_yticklabels([7519,7519," ",7518," ",7517," ",7516," ",7515])
ax3.set_xlabel('UTM coordinates (km)')
ax3.grid()

plt.show()
fig.savefig('ia_2974.pdf', dpi=200, transparent=True, bbox_inches='tight')

# %%
fig, axes = plt.subplots(nrows=1, ncols=1)
fig.set_size_inches(30, 20)

plt.tight_layout(pad=0.5, w_pad=2.5, h_pad=2.0)
ax1 = plt.subplot(131) # creates first axis
i1 = ax1.imshow(imp_obs_2974,cmap='jet',vmin=20000,vmax=35000)
cb1 = plt.colorbar(i1, shrink=0.30)
plt.contourf(imp_obs_2974, 15, alpha=.75, cmap='jet',vmin=20000,vmax=35000)
plt.title('$Z_{obs}$ ($ft/s.g/cm^3$)',fontsize=24)
plt.text(NA02[0],NA02[1], 'NA02');plt.plot(NA02[0],NA02[1],'.k')
plt.text(NA04[0],NA04[1], 'NA04');plt.plot(NA04[0],NA04[1],'.k')
plt.text(NA07[0],NA07[1], 'NA07');plt.plot(NA07[0],NA07[1],'.k')
plt.text(NA12[0],NA12[1], 'NA12');plt.plot(NA12[0],NA12[1],'.k')
plt.text(NA37[0],NA37[1], 'NA37');plt.plot(NA37[0],NA37[1],'.k')
plt.text(RJS19[0],RJS19[1], 'RJS19');plt.plot(RJS19[0],RJS19[1],'.k')
plt.text(RJS42[0],RJS42[1], 'RJS42');plt.plot(RJS42[0],RJS42[1],'.k')
#-------------------------#
ax1.set_xticklabels([351,351,352,353,354,355,356])
ax1.set_yticklabels([7519,7519," ",7518," ",7517," ",7516," ",7515])
ax1.set_ylabel('UTM coordinates (km)',fontsize=14)
ax1.set_xlabel('UTM coordinates (km)',fontsize=14)
ax1.grid()

plt.show()
fig.savefig('ia_2974a_dis.pdf', dpi=200, transparent=True, bbox_inches='tight')

# %%
fig, axes = plt.subplots(nrows=1, ncols=1)
fig.set_size_inches(30, 20)

plt.tight_layout(pad=0.5, w_pad=2.5, h_pad=2.0)
ax1 = plt.subplot(131) # creates first axis
i1 = ax1.imshow(imp_km_2974,cmap='jet',vmin=20000,vmax=35000)
cb1 = plt.colorbar(i1, shrink=0.30)
plt.contourf(imp_km_2974, 15, alpha=.75, cmap='jet',vmin=20000,vmax=35000)
plt.title('$Z_{KM}$ ($ft/s.g/cm^3$)',fontsize=24)
plt.text(NA02[0],NA02[1], 'NA02');plt.plot(NA02[0],NA02[1],'.k')
plt.text(NA04[0],NA04[1], 'NA04');plt.plot(NA04[0],NA04[1],'.k')
plt.text(NA07[0],NA07[1], 'NA07', color='white');plt.plot(NA07[0],NA07[1],'.w')
plt.text(NA12[0],NA12[1], 'NA12');plt.plot(NA12[0],NA12[1],'.k')
plt.text(NA37[0],NA37[1], 'NA37');plt.plot(NA37[0],NA37[1],'.k')
plt.text(RJS19[0],RJS19[1], 'RJS19');plt.plot(RJS19[0],RJS19[1],'.k')
plt.text(RJS42[0],RJS42[1], 'RJS42');plt.plot(RJS42[0],RJS42[1],'.k')
#-------------------------#
ax1.set_xticklabels([351,351,352,353,354,355,356])
ax1.set_yticklabels([7519,7519," ",7518," ",7517," ",7516," ",7515])
ax1.set_ylabel('UTM coordinates (km)',fontsize=14)
ax1.set_xlabel('UTM coordinates (km)',fontsize=14)
ax1.grid()

plt.show()
fig.savefig('ia_2974b_dis.pdf', dpi=200, transparent=True, bbox_inches='tight')

# %%
fig, axes = plt.subplots(nrows=1, ncols=1)
fig.set_size_inches(30, 20)

plt.tight_layout(pad=0.5, w_pad=2.5, h_pad=2.0)
ax1 = plt.subplot(131) # creates first axis
i1 = ax1.imshow(imp_aug_2974,cmap='jet',vmin=20000,vmax=35000)
cb1 = plt.colorbar(i1, shrink=0.30)
plt.contourf(imp_aug_2974, 15, alpha=.75, cmap='jet',vmin=20000,vmax=35000)
plt.title('$Z_{e}$ ($ft/s.g/cm^3$)',fontsize=24)
plt.text(NA02[0],NA02[1], 'NA02', color='white');plt.plot(NA02[0],NA02[1],'.w')
plt.text(NA04[0],NA04[1], 'NA04', color='white');plt.plot(NA04[0],NA04[1],'.w')
plt.text(NA07[0],NA07[1], 'NA07');plt.plot(NA07[0],NA07[1],'.k')
plt.text(NA12[0],NA12[1], 'NA12');plt.plot(NA12[0],NA12[1],'.k')
plt.text(NA37[0],NA37[1], 'NA37', color='white');plt.plot(NA37[0],NA37[1],'.w')
plt.text(RJS19[0],RJS19[1], 'RJS19');plt.plot(RJS19[0],RJS19[1],'.k')
plt.text(RJS42[0],RJS42[1], 'RJS42');plt.plot(RJS42[0],RJS42[1],'.k')
#-------------------------#
ax1.set_xticklabels([351,351,352,353,354,355,356])
ax1.set_yticklabels([7519,7519," ",7518," ",7517," ",7516," ",7515])
ax1.set_ylabel('UTM coordinates (km)',fontsize=14)
ax1.set_xlabel('UTM coordinates (km)',fontsize=14)
ax1.grid()

plt.show()
fig.savefig('ia_2974c_dis.pdf', dpi=200, transparent=True, bbox_inches='tight')

# %%
imp_aug_3083 = np.load('imp_aug_mapa876.npy')
imp_obs_3083 = np.load('imp_obs_mapa876.npy')
imp_km_3083  = np.load('imp_km_mapa876.npy')

plt.matshow(imp_obs_3083)
plt.colorbar()
plt.show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=3)
fig.set_size_inches(15, 10)

#tick = np.linspace(np.min(imp_obs_2974),np.max(imp_obs_2974),10)

plt.tight_layout(pad=0.5, w_pad=2.5, h_pad=2.0)
ax1 = plt.subplot(131) # creates first axis
i1 = ax1.imshow(imp_obs_3083,cmap='jet',vmin=22000,vmax=35000)
cb1 = plt.colorbar(i1, shrink=0.30)
plt.contourf(imp_obs_3083, 15, alpha=.75, cmap='jet',vmin=22000,vmax=35000)
plt.title('$Z_{obs}$')

plt.text(NA02[0],NA02[1], 'NA02');plt.plot(NA02[0],NA02[1],'.k')
plt.text(NA04[0],NA04[1], 'NA04', color='white');plt.plot(NA04[0],NA04[1],'.w')
plt.text(NA07[0],NA07[1], 'NA07');plt.plot(NA07[0],NA07[1],'.k')
plt.text(NA12[0],NA12[1], 'NA12');plt.plot(NA12[0],NA12[1],'.k')
plt.text(NA37[0],NA37[1], 'NA37');plt.plot(NA37[0],NA37[1],'.k')
plt.text(RJS19[0],RJS19[1], 'RJS19');plt.plot(RJS19[0],RJS19[1],'.k')
plt.text(RJS42[0],RJS42[1], 'RJS42');plt.plot(RJS42[0],RJS42[1],'.k')
#-------------------------#
ax1.set_xticklabels([351,351,352,353,354,355,356])
ax1.set_yticklabels([7519,7519," ",7518," ",7517," ",7516," ",7515])
ax1.set_ylabel('UTM coordinates (km)')
ax1.set_xlabel('UTM coordinates (km)')
ax1.grid()
#------------------------------------------------------------------------------------------------------#
ax2 = plt.subplot(132) # creates second axis
i2=ax2.imshow(imp_km_3083,cmap='jet',vmin=22000,vmax=35000)
cb2 = plt.colorbar(i2, shrink=0.30)
plt.contourf(imp_km_3083, 15, alpha=.75, cmap='jet',vmin=22000,vmax=35000)
plt.title('$Z_{KM}$')

plt.text(NA02[0],NA02[1], 'NA02');plt.plot(NA02[0],NA02[1],'.k')
plt.text(NA04[0],NA04[1], 'NA04', color='white');plt.plot(NA04[0],NA04[1],'.w')
plt.text(NA07[0],NA07[1], 'NA07');plt.plot(NA07[0],NA07[1],'.k')
plt.text(NA12[0],NA12[1], 'NA12');plt.plot(NA12[0],NA12[1],'.k')
plt.text(NA37[0],NA37[1], 'NA37');plt.plot(NA37[0],NA37[1],'.k')
plt.text(RJS19[0],RJS19[1], 'RJS19');plt.plot(RJS19[0],RJS19[1],'.k')
plt.text(RJS42[0],RJS42[1], 'RJS42');plt.plot(RJS42[0],RJS42[1],'.k')
#-------------------------#
ax2.set_xticklabels([351,351,352,353,354,355,356])
ax2.set_yticklabels([7519,7519," ",7518," ",7517," ",7516," ",7515])
ax2.set_xlabel('UTM coordinates (km)')
ax2.grid()
#------------------------------------------------------------------------------------------------------#
#plt.tight_layout(pad=0.5, w_pad=2.5, h_pad=2.0)
ax3 = plt.subplot(133) # creates first axis
i3 = ax3.imshow(imp_aug_3083,cmap='jet',vmin=22000,vmax=35000)
cb3 = plt.colorbar(i3, shrink=0.30)
plt.contourf(imp_aug_3083, 15, alpha=.75, cmap='jet',vmin=22000,vmax=35000)
plt.title('$Z_e$')

plt.text(NA02[0],NA02[1], 'NA02');plt.plot(NA02[0],NA02[1],'.k')
plt.text(NA04[0],NA04[1], 'NA04');plt.plot(NA04[0],NA04[1],'.k')
plt.text(NA07[0],NA07[1], 'NA07');plt.plot(NA07[0],NA07[1],'.k')
plt.text(NA12[0],NA12[1], 'NA12');plt.plot(NA12[0],NA12[1],'.k')
plt.text(NA37[0],NA37[1], 'NA37');plt.plot(NA37[0],NA37[1],'.k')
plt.text(RJS19[0],RJS19[1], 'RJS19');plt.plot(RJS19[0],RJS19[1],'.k')
plt.text(RJS42[0],RJS42[1], 'RJS42');plt.plot(RJS42[0],RJS42[1],'.k')
#-------------------------#
ax3.set_xticklabels([351,351,352,353,354,355,356])
ax3.set_yticklabels([7519,7519," ",7518," ",7517," ",7516," ",7515])
ax3.set_xlabel('UTM coordinates (km)')
ax3.grid()

plt.show()
fig.savefig('ia_3083.pdf', dpi=200, transparent=True, bbox_inches='tight')

# %%
fig, axes = plt.subplots(nrows=1, ncols=1)
fig.set_size_inches(30, 20)

plt.tight_layout(pad=0.5, w_pad=2.5, h_pad=2.0)
ax1 = plt.subplot(131) # creates first axis
i1 = ax1.imshow(imp_obs_3083,cmap='jet',vmin=20000,vmax=35000)
cb1 = plt.colorbar(i1, shrink=0.30)
plt.contourf(imp_obs_3083, 15, alpha=.75, cmap='jet',vmin=20000,vmax=35000)
plt.title('$Z_{obs}$ ($ft/s.g/cm^3$)',fontsize=24)
plt.text(NA02[0],NA02[1], 'NA02');plt.plot(NA02[0],NA02[1],'.k')
plt.text(NA04[0],NA04[1], 'NA04');plt.plot(NA04[0],NA04[1],'.k')
plt.text(NA07[0],NA07[1], 'NA07');plt.plot(NA07[0],NA07[1],'.k')
plt.text(NA12[0],NA12[1], 'NA12');plt.plot(NA12[0],NA12[1],'.k')
plt.text(NA37[0],NA37[1], 'NA37');plt.plot(NA37[0],NA37[1],'.k')
plt.text(RJS19[0],RJS19[1], 'RJS19');plt.plot(RJS19[0],RJS19[1],'.k')
plt.text(RJS42[0],RJS42[1], 'RJS42');plt.plot(RJS42[0],RJS42[1],'.k')
#-------------------------#
ax1.set_xticklabels([351,351,352,353,354,355,356])
ax1.set_yticklabels([7519,7519," ",7518," ",7517," ",7516," ",7515])
ax1.set_ylabel('UTM coordinates (km)',fontsize=14)
ax1.set_xlabel('UTM coordinates (km)',fontsize=14)
ax1.grid()

plt.show()
fig.savefig('ia_3083a_dis.pdf', dpi=200, transparent=True, bbox_inches='tight')

# %%
fig, axes = plt.subplots(nrows=1, ncols=1)
fig.set_size_inches(30, 20)

plt.tight_layout(pad=0.5, w_pad=2.5, h_pad=2.0)
ax1 = plt.subplot(131) # creates first axis
i1 = ax1.imshow(imp_km_3083,cmap='jet',vmin=20000,vmax=35000)
cb1 = plt.colorbar(i1, shrink=0.30)
plt.contourf(imp_km_3083, 15, alpha=.75, cmap='jet',vmin=20000,vmax=35000)
plt.title('$Z_{KM}$ ($ft/s.g/cm^3$)',fontsize=24)
plt.text(NA02[0],NA02[1], 'NA02', color='white');plt.plot(NA02[0],NA02[1],'.w')
plt.text(NA04[0],NA04[1], 'NA04', color='black');plt.plot(NA04[0],NA04[1],'.k')
plt.text(NA07[0],NA07[1], 'NA07');plt.plot(NA07[0],NA07[1],'.k')
plt.text(NA12[0],NA12[1], 'NA12');plt.plot(NA12[0],NA12[1],'.k')
plt.text(NA37[0],NA37[1], 'NA37');plt.plot(NA37[0],NA37[1],'.k')
plt.text(RJS19[0],RJS19[1], 'RJS19');plt.plot(RJS19[0],RJS19[1],'.k')
plt.text(RJS42[0],RJS42[1], 'RJS42');plt.plot(RJS42[0],RJS42[1],'.k')
#-------------------------#
ax1.set_xticklabels([351,351,352,353,354,355,356])
ax1.set_yticklabels([7519,7519," ",7518," ",7517," ",7516," ",7515])
ax1.set_ylabel('UTM coordinates (km)',fontsize=14)
ax1.set_xlabel('UTM coordinates (km)',fontsize=14)
ax1.grid()

plt.show()
fig.savefig('ia_3083b_dis.pdf', dpi=200, transparent=True, bbox_inches='tight')

# %%
fig, axes = plt.subplots(nrows=1, ncols=1)
fig.set_size_inches(30, 20)

plt.tight_layout(pad=0.5, w_pad=2.5, h_pad=2.0)
ax1 = plt.subplot(131) # creates first axis
i1 = ax1.imshow(imp_aug_3083,cmap='jet',vmin=20000,vmax=35000)
cb1 = plt.colorbar(i1, shrink=0.30)
plt.contourf(imp_aug_3083, 15, alpha=.75, cmap='jet',vmin=20000,vmax=35000)
plt.title('$Z_{e}$ ($ft/s.g/cm^3$)',fontsize=24)
plt.text(NA02[0],NA02[1], 'NA02');plt.plot(NA02[0],NA02[1],'.k')
plt.text(NA04[0],NA04[1], 'NA04');plt.plot(NA04[0],NA04[1],'.k')
plt.text(NA07[0],NA07[1], 'NA07');plt.plot(NA07[0],NA07[1],'.k')
plt.text(NA12[0],NA12[1], 'NA12');plt.plot(NA12[0],NA12[1],'.k')
plt.text(NA37[0],NA37[1], 'NA37');plt.plot(NA37[0],NA37[1],'.k')
plt.text(RJS19[0],RJS19[1], 'RJS19');plt.plot(RJS19[0],RJS19[1],'.k')
plt.text(RJS42[0],RJS42[1], 'RJS42');plt.plot(RJS42[0],RJS42[1],'.k')
#-------------------------#
ax1.set_xticklabels([351,351,352,353,354,355,356])
ax1.set_yticklabels([7519,7519," ",7518," ",7517," ",7516," ",7515])
ax1.set_ylabel('UTM coordinates (km)',fontsize=14)
ax1.set_xlabel('UTM coordinates (km)',fontsize=14)
ax1.grid()

plt.show()
fig.savefig('ia_3083c_dis.pdf', dpi=200, transparent=True, bbox_inches='tight')

# %%
imp_aug_3103 = np.load('imp_aug_mapa1007.npy')
imp_obs_3103 = np.load('imp_obs_mapa1007.npy')
imp_km_3103  = np.load('imp_km_mapa1007.npy')

plt.matshow(imp_obs_3103)
plt.colorbar()
plt.show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=3)
fig.set_size_inches(15, 10)

#tick = np.linspace(np.min(imp_obs_2974),np.max(imp_obs_2974),10)

plt.tight_layout(pad=0.5, w_pad=2.5, h_pad=2.0)
ax1 = plt.subplot(131) # creates first axis
i1 = ax1.imshow(imp_obs_3103,cmap='jet',vmin=22500,vmax=33500)
cb1 = plt.colorbar(i1, shrink=0.30)
plt.contourf(imp_obs_3103, 15, alpha=.75, cmap='jet',vmin=22500,vmax=33500)
plt.title('$Z_{obs}$ ($ft/s.g/cm^3$)')

plt.text(NA02[0],NA02[1], 'NA02');plt.plot(NA02[0],NA02[1],'.k')
plt.text(NA04[0],NA04[1], 'NA04');plt.plot(NA04[0],NA04[1],'.k')
plt.text(NA07[0],NA07[1], 'NA07');plt.plot(NA07[0],NA07[1],'.k')
plt.text(NA12[0],NA12[1], 'NA12');plt.plot(NA12[0],NA12[1],'.k')
plt.text(NA37[0],NA37[1], 'NA37');plt.plot(NA37[0],NA37[1],'.k')
plt.text(RJS19[0],RJS19[1], 'RJS19');plt.plot(RJS19[0],RJS19[1],'.k')
plt.text(RJS42[0],RJS42[1], 'RJS42');plt.plot(RJS42[0],RJS42[1],'.k')
#-------------------------#
ax1.set_xticklabels([351,351,352,353,354,355,356])
ax1.set_yticklabels([7519,7519," ",7518," ",7517," ",7516," ",7515])
ax1.set_ylabel('UTM coordinates (km)')
ax1.set_xlabel('UTM coordinates (km)')
ax1.grid()
#------------------------------------------------------------------------------------------------------#
ax2 = plt.subplot(132) # creates second axis
i2=ax2.imshow(imp_km_3103,cmap='jet',vmin=22500,vmax=33500)
cb2 = plt.colorbar(i2, shrink=0.30)
plt.contourf(imp_km_3103, 15, alpha=.75, cmap='jet',vmin=22500,vmax=33500)
plt.title('$Z_{KM}$')

plt.text(NA02[0],NA02[1], 'NA02');plt.plot(NA02[0],NA02[1],'.k')
plt.text(NA04[0],NA04[1], 'NA04', color='white');plt.plot(NA04[0],NA04[1],'.w')
plt.text(NA07[0],NA07[1], 'NA07');plt.plot(NA07[0],NA07[1],'.k')
plt.text(NA12[0],NA12[1], 'NA12');plt.plot(NA12[0],NA12[1],'.k')
plt.text(NA37[0],NA37[1], 'NA37', color='white');plt.plot(NA37[0],NA37[1],'.w')
plt.text(RJS19[0],RJS19[1], 'RJS19');plt.plot(RJS19[0],RJS19[1],'.k')
plt.text(RJS42[0],RJS42[1], 'RJS42');plt.plot(RJS42[0],RJS42[1],'.k')
#-------------------------#
ax2.set_xticklabels([351,351,352,353,354,355,356])
ax2.set_yticklabels([7519,7519," ",7518," ",7517," ",7516," ",7515])
ax2.set_xlabel('UTM coordinates (km)')
ax2.grid()
#------------------------------------------------------------------------------------------------------#
#plt.tight_layout(pad=0.5, w_pad=2.5, h_pad=2.0)
ax3 = plt.subplot(133) # creates first axis
i3 = ax3.imshow(imp_aug_3103,cmap='jet',vmin=22500,vmax=33500)
cb3 = plt.colorbar(i3, shrink=0.30)
plt.contourf(imp_aug_3103, 15, alpha=.75, cmap='jet',vmin=22500,vmax=33500)
plt.title('$Z_e$')

plt.text(NA02[0],NA02[1], 'NA02');plt.plot(NA02[0],NA02[1],'.k')
plt.text(NA04[0],NA04[1], 'NA04');plt.plot(NA04[0],NA04[1],'.k')
plt.text(NA07[0],NA07[1], 'NA07');plt.plot(NA07[0],NA07[1],'.k')
plt.text(NA12[0],NA12[1], 'NA12');plt.plot(NA12[0],NA12[1],'.k')
plt.text(NA37[0],NA37[1], 'NA37');plt.plot(NA37[0],NA37[1],'.k')
plt.text(RJS19[0],RJS19[1], 'RJS19');plt.plot(RJS19[0],RJS19[1],'.k')
plt.text(RJS42[0],RJS42[1], 'RJS42');plt.plot(RJS42[0],RJS42[1],'.k')
#-------------------------#
ax3.set_xticklabels([351,351,352,353,354,355,356])
ax3.set_yticklabels([7519,7519," ",7518," ",7517," ",7516," ",7515])
ax3.set_xlabel('UTM coordinates (km)')
ax3.grid()

plt.show()
fig.savefig('ia_3103.pdf', dpi=200, transparent=True, bbox_inches='tight')

# %%
fig, axes = plt.subplots(nrows=1, ncols=1)
fig.set_size_inches(30, 20)

plt.tight_layout(pad=0.5, w_pad=2.5, h_pad=2.0)
ax1 = plt.subplot(131) # creates first axis
i1 = ax1.imshow(imp_obs_3103,cmap='jet',vmin=20000,vmax=35000)
cb1 = plt.colorbar(i1, shrink=0.30)
plt.contourf(imp_obs_3103, 15, alpha=.75, cmap='jet',vmin=20000,vmax=35000)
plt.title('$Z_{obs}$ ($ft/s.g/cm^3$)',fontsize=24)
plt.text(NA02[0],NA02[1], 'NA02');plt.plot(NA02[0],NA02[1],'.k')
plt.text(NA04[0],NA04[1], 'NA04', color='white');plt.plot(NA04[0],NA04[1],'.w')
plt.text(NA07[0],NA07[1], 'NA07');plt.plot(NA07[0],NA07[1],'.k')
plt.text(NA12[0],NA12[1], 'NA12');plt.plot(NA12[0],NA12[1],'.k')
plt.text(NA37[0],NA37[1], 'NA37');plt.plot(NA37[0],NA37[1],'.k')
plt.text(RJS19[0],RJS19[1], 'RJS19');plt.plot(RJS19[0],RJS19[1],'.k')
plt.text(RJS42[0],RJS42[1], 'RJS42');plt.plot(RJS42[0],RJS42[1],'.k')
#-------------------------#
ax1.set_xticklabels([351,351,352,353,354,355,356])
ax1.set_yticklabels([7519,7519," ",7518," ",7517," ",7516," ",7515])
ax1.set_ylabel('UTM coordinates (km)',fontsize=14)
ax1.set_xlabel('UTM coordinates (km)',fontsize=14)
ax1.grid()

plt.show()
fig.savefig('ia_3103a_dis.pdf', dpi=200, transparent=True, bbox_inches='tight')

# %%
fig, axes = plt.subplots(nrows=1, ncols=1)
fig.set_size_inches(30, 20)

plt.tight_layout(pad=0.5, w_pad=2.5, h_pad=2.0)
ax1 = plt.subplot(131) # creates first axis
i1 = ax1.imshow(imp_km_3103,cmap='jet',vmin=20000,vmax=35000)
cb1 = plt.colorbar(i1, shrink=0.30)
plt.contourf(imp_km_3103, 15, alpha=.75, cmap='jet',vmin=20000,vmax=35000)
plt.title('$Z_{KM}$ ($ft/s.g/cm^3$)',fontsize=24)
plt.text(NA02[0],NA02[1], 'NA02', color='white');plt.plot(NA02[0],NA02[1],'.w')
plt.text(NA04[0],NA04[1], 'NA04', color='white');plt.plot(NA04[0],NA04[1],'.w')
plt.text(NA07[0],NA07[1], 'NA07');plt.plot(NA07[0],NA07[1],'.k')
plt.text(NA12[0],NA12[1], 'NA12');plt.plot(NA12[0],NA12[1],'.k')
plt.text(NA37[0],NA37[1], 'NA37', color='white');plt.plot(NA37[0],NA37[1],'.w')
plt.text(RJS19[0],RJS19[1], 'RJS19');plt.plot(RJS19[0],RJS19[1],'.k')
plt.text(RJS42[0],RJS42[1], 'RJS42');plt.plot(RJS42[0],RJS42[1],'.k')
#-------------------------#
ax1.set_xticklabels([351,351,352,353,354,355,356])
ax1.set_yticklabels([7519,7519," ",7518," ",7517," ",7516," ",7515])
ax1.set_ylabel('UTM coordinates (km)',fontsize=14)
ax1.set_xlabel('UTM coordinates (km)',fontsize=14)
ax1.grid()

plt.show()
fig.savefig('ia_3103b_dis.pdf', dpi=200, transparent=True, bbox_inches='tight')

# %%
fig, axes = plt.subplots(nrows=1, ncols=1)
fig.set_size_inches(30, 20)

plt.tight_layout(pad=0.5, w_pad=2.5, h_pad=2.0)
ax1 = plt.subplot(131) # creates first axis
i1 = ax1.imshow(imp_aug_3103,cmap='jet',vmin=20000,vmax=35000)
cb1 = plt.colorbar(i1, shrink=0.30)
plt.contourf(imp_aug_3103, 15, alpha=.75, cmap='jet',vmin=20000,vmax=35000)
plt.title('$Z_{e}$ ($ft/s.g/cm^3$)',fontsize=24)
plt.text(NA02[0],NA02[1], 'NA02');plt.plot(NA02[0],NA02[1],'.k')
plt.text(NA04[0],NA04[1], 'NA04');plt.plot(NA04[0],NA04[1],'.k')
plt.text(NA07[0],NA07[1], 'NA07');plt.plot(NA07[0],NA07[1],'.k')
plt.text(NA12[0],NA12[1], 'NA12');plt.plot(NA12[0],NA12[1],'.k')
plt.text(NA37[0],NA37[1], 'NA37');plt.plot(NA37[0],NA37[1],'.k')
plt.text(RJS19[0],RJS19[1], 'RJS19');plt.plot(RJS19[0],RJS19[1],'.k')
plt.text(RJS42[0],RJS42[1], 'RJS42');plt.plot(RJS42[0],RJS42[1],'.k')
#-------------------------#
ax1.set_xticklabels([351,351,352,353,354,355,356])
ax1.set_yticklabels([7519,7519," ",7518," ",7517," ",7516," ",7515])
ax1.set_ylabel('UTM coordinates (km)',fontsize=14)
ax1.set_xlabel('UTM coordinates (km)',fontsize=14)
ax1.grid()

plt.show()
fig.savefig('ia_3103c_dis.pdf', dpi=200, transparent=True, bbox_inches='tight')
